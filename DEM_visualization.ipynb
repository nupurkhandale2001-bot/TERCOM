# %%
pip install rasterio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 76.3 MB/s eta 0:00:00
# ...

# %%
import rasterio
import matplotlib.pyplot as plt

# %%
# Open GeoTIFF
with rasterio.open("/content/AmrabadTigerReserve_Processsed.tif") as src:
    img = src.read(1)   # read first band

# %%
plt.imshow(img, cmap="terrain")  # good for elevation maps
plt.colorbar()
plt.show()
